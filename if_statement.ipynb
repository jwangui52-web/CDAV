# %% [markdown]
# <a href="https://colab.research.google.com/github/jwangui52-web/CDAV/blob/main/if_statement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
is_raining=True
if is_raining:
  print("stay indoors")
# Out:
# stay indoors

# %%
if not is_raining:
  print("go out")

# %% [markdown]
# #Bank ATM-v1

# %%
balance=500
amt=float(input("How much do you want to withdraw"))
if balance<amt:
  print("insufficient balance")
  print("top up and try again")
if balance>=amt:
  print("withdraw successful")
# Out:
# How much do you want to withdraw 5000
# insufficient balance
# top up and try again

# %%
marks=int(input("enter marks"))

if marks>=50:
  print("well done")
if marks<=50:
  print("improve")
# Out:
# enter marks 80
# well done

# %% [markdown]
# #if...else

# %%
is_raining=False
if is_raining:
  print("stay indoors")
else:
  print("go out")
# Out:
# go out

# %%
balance=500
amt=float(input("How much do you want to withdraw"))
if balance<amt:
  print("insufficient balance")
  print("top up and try again")
else:
  print("withdraw successful")
# Out:
# How much do you want to withdraw 5000
# insufficient balance
# top up and try again

# %%
Access=str(input("what is the password "))
if Access=="Python123":
  print("access")
else:
  print("do not access")
# Out:
# what is the password Python123
# access

# %% [markdown]
# #Umbrella advisor

# %%
is_cloudy=input("If its cloudy,type 1.if not type 2")
is_raining=input("If its raining,type 1.if not type 2")
if is_raining=="1":
  print("use an umbrella")
elif is_cloudy=="1":
  print("carry an umbrella")
else:
  print("you do not need an umbrella")
# Out:
# If its cloudy,type 1.if not type 21
# If its raining,type 1.if not type 21
# use an umbrella

# %%
a=1
b=2
c=3
print(a==b and b==c)
print(a<b or b>c)
print(a<b and b>c)
# Out:
# False
# True
# False

# %% [markdown]
# write a program that takes a value from the user,the program should print
# :divisible by 2 if the value is divisible by 2
# :divisible by 3 if the value is divisible by 3
# :divisible by both 2 and 3 if the value is divisible by both 2 and 3
# otherwise it should print not divisible by 2 and 3

# %%
val=int(input("enter a value"))
if val%2==0 and val%3==0:
print("the value is divisible by both 2 and 3")
elif val%2==0:
print("it is divisible by 2")
elif val%3==0:
print("it is divisible by 3")
else:
print("it is divisible by both 2 and 3")

# %%
text="Python"
print(text[0:2])#'Py'(indices 0,1)
# Out:
# Py
