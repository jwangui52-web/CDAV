# %% [markdown]
# <a href="https://colab.research.google.com/github/jwangui52-web/CDAV/blob/main/Personal_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
number=15
if number>0:
  print("number is positive")
# Out:
# number is positive

# %%
age=20
if age>=18:
  print("you can drive")
  print("you can vote")
  print("you can start university")
  print("you can legally get married")
  print("you have all legal rights")
# Out:
# you can drive
# you can vote
# you can start university
# you can legally get married
# you have all legal rights

# %%
a=33
b=33
if b>a:
  print("b is greater than a")
elif b==a:
  print("b is equal to a")
# Out:
# b is equal to a

# %%
score=75
if score>=90:
 print("Grade A")
elif score>=80:
 print("Grade B")
elif score>=70:
 print("Grade C")
elif score>=60:
 print("Grade D")
# Out:
# Grade C

# %%
number=7
if number%2==0:
 print("number is even")
else:
  print("number is odd")
# Out:
# number is odd

# %%
temperature=22
if temperature>30:
 print("it's hot outside")
elif temperature>20:
 print("it's warm outside")
elif temperature>10:
 print("it's cool outside")
else:
  print("it's cold outside")
# Out:
# it's warm outside
