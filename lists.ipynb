# %% [markdown]
# <a href="https://colab.research.google.com/github/jwangui52-web/CDAV/blob/main/lists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lists

# %%
students=["john,mary,evans"]
print(students)
print(type(students))
# Out:
# ['john,mary,evans']
# <class 'list'>

# %%
#creating lists using typecasting
name="john"
name=list(name)
print(name)
# Out:
# ['j', 'o', 'h', 'n']

# %%
#creating a list using the split method
school="soma,riverdale,strathmore"
school.split(",")
# Out:
# ['soma', 'riverdale', 'strathmore']

# %% [markdown]
# # Escape characters and string formatting

# %%
paragraph="""
this is a line
this is another line
this has '
this has a \
"""
print(paragraph)
# Out:
# this is a line
# this is another line
# this has '
# this has a

# %%
introduction="i am John.\nMy age is 18"
print(introduction)
# Out:
# i am John.
# My age is 18

# %%
introduction="\ti am John.\n\tMy age is 18"
print(introduction)
# Out:
# 	i am John.
# 	My age is 18

# %%
introduction='I\'m John.\nMy age is 18'
print(introduction)
# Out:
# I'm John.
# My age is 18

# %%
paragraph="""
this is a line
this is another line
this has '
this has a \
"""
print(paragraph.replace("\n","\t"))
# Out:
# 	this is a line	this is another line	this has '	this has a

# %% [markdown]
# #mini school dataset(csv)

# %%
data="""name,gender,grade
john,m,76
jane,f,82
joseph,m,84
susan,f,72
"""

# %%
rows=data.split("\n")
print(rows)
print(rows[0].split(","))
# Out:
# ['name,gender,grade', 'john,m,76', 'jane,f,82', 'joseph,m,84', 'susan,f,72', '']
# ['name', 'gender', 'grade']

# %%
print(data.split("\n")[0].split(","))
# Out:
# ['name', 'gender', 'grade']

# %%
cols=data.split("\n")[0].split(",")
print(data.split("\n")[3].split(",")[2])
# Out:
# 84

# %%
cols[::-1]
# Out:
# ['grade', 'gender', 'name']

# %%
cols[1]="weight"
print(cols)
# Out:
# ['name', 'weight', 'grade']

# %%
cols.append("age")
print(cols)
# Out:
# ['name', 'weight', 'grade', 'age']

# %%
cols.pop()
'age'
# Out:
# 'age'

# %%
marks=[20,34,18,45,4,7]
marks.sort(reverse=True)

# %%
print(marks)
# Out:
# [45, 34, 20, 18, 7, 4]

# %%
vals=[10,20,30]
vals.append(40)
print(vals)
# Out:
# [10, 20, 30, 40]

# %%
vals.insert(1,15)
print(vals)
# Out:
# [15, 10, 15, 15, 20, 30, 40]

# %%
avg=sum(vals)/len(vals)
print(f"the list contains{vals}.its averageis{avg}")
# Out:
# the list contains[10, 15, 15, 20, 30, 40].its averageis21.666666666666668

# %% [markdown]
# #create a program that keep asking the user for numbers until they pres=
# the program should then output
#
# .sum
# .lowest val
# .highest val
# .average val
# The program should not crash if the user enters a non-numerical val

# %%
number=input("Enter as many numbers").Type'=' to finish
while number!="=":
  print()
