# %% [markdown]
# <a href="https://colab.research.google.com/github/jwangui52-web/CDAV/blob/main/pandas_day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #most streamed artist on spotify.

# %%
# !pip install pandas

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.2'

# %%
df=pd.read_excel("/content/Most Streamed Artists on Spotify (17_07_2026).csv.xlsx")
df.head()
# Out:
#           Artist     Sex        Country Langugage Primary Genre  Artist Type  \
# 0          Drake    Male         Canada   English       Hip-Hop         Solo
# 1   Taylor Swift  Female  United States   English           Pop         Solo
# 2      Bad Bunny    Male  United States   Spanish     Reggaeton         Solo
# 3     The Weeknd    Male         Canada   English           R&B         Solo
# 4  Justin Bieber    Male         Canada   English           Pop         Solo
#
#    Total Streams (in millions)  Lead Streams (in millions)  \
# 0                     137492.1                     94851.1
# 1                     127861.0                    126177.3
# 2                     125899.8                     82189.3
# 3                      95703.2                     77189.4
# 4                      78104.4                     48316.2
#
#    Feature Streams (in millions)  Solo Streams (in millions)
# 0                        42640.9                     53323.9
# ...

# %%
df.tail()
# Out:
#           Artist    Sex         Country Langugage Primary Genre  Artist Type  \
# 495     The Cure   Male  United Kingdom   English          Rock        Group
# 496  The MarÃ­as  Mixed   United States   English           Pop        Group
# 497  Limp Bizkit   Male   United States   English      Nu Metal        Group
# 498         Korn   Male   United States   English         Metal        Group
# 499  Omar Courtz   Male   United States   Spanish     Reggaeton         Solo
#
#      Total Streams (in millions)  Lead Streams (in millions)  \
# 495                       7034.1                      7035.0
# 496                       7029.1                      5774.4
# 497                       7018.9                      7018.4
# 498                       6976.4                      4188.4
# 499                       6972.0                      6956.0
#
#      Feature Streams (in millions)  Solo Streams (in millions)
# 495                            3.3                      6940.1
# ...

# %%
df.head(10)
# Out:
#           Artist     Sex         Country Langugage Primary Genre  Artist Type  \
# 0          Drake    Male          Canada   English       Hip-Hop         Solo
# 1   Taylor Swift  Female   United States   English           Pop         Solo
# 2      Bad Bunny    Male   United States   Spanish     Reggaeton         Solo
# 3     The Weeknd    Male          Canada   English           R&B         Solo
# 4  Justin Bieber    Male          Canada   English           Pop         Solo
# 5  Ariana Grande  Female   United States   English           Pop         Solo
# 6   Travis Scott    Male   United States   English       Hip-Hop         Solo
# 7     Kanye West    Male   United States   English       Hip-Hop         Solo
# 8     Ed Sheeran    Male  United Kingdom   English           Pop         Solo
# 9         Eminem    Male   United States   English       Hip-Hop         Solo
#
#    Total Streams (in millions)  Lead Streams (in millions)  \
# ...

# %%
df.tail(12)
# Out:
#                      Artist    Sex         Country Langugage  \
# 488  Grupo Marca Registrada   Male          Mexico   Spanish
# 489            benny blanco   Male   United States   English
# 490                     JID   Male   United States   English
# 491               YNW Melly   Male   United States   English
# 492            Juan Gabriel   Male          Mexico   Spanish
# 493          Los Temerarios   Male          Mexico   Spanish
# 494              Jason Mraz   Male   United States   English
# 495                The Cure   Male  United Kingdom   English
# 496             The MarÃ­as  Mixed   United States   English
# 497             Limp Bizkit   Male   United States   English
# 498                    Korn   Male   United States   English
# 499             Omar Courtz   Male   United States   Spanish
#
#         Primary Genre  Artist Type  Total Streams (in millions)  \
# 488  Regional Mexican        Group                       7123.4
# ...

# %%
df.shape
# Out:
# (500, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Artist                         500 non-null    object
#  1   Sex                            500 non-null    object
#  2   Country                        500 non-null    object
#  3   Langugage                      500 non-null    object
#  4   Primary Genre                  500 non-null    object
#  5    Artist Type                   500 non-null    object
#  6   Total Streams (in millions)    500 non-null    float64
#  7   Lead Streams (in millions)     497 non-null    float64
#  8   Feature Streams (in millions)  468 non-null    float64
#  9   Solo Streams (in millions)     493 non-null    float64
# dtypes: float64(4), object(6)
# memory usage: 39.2+ KB

# %%
df.describe()
# Out:
#        Total Streams (in millions)  Lead Streams (in millions)  \
# count                   500.000000                  497.000000
# mean                  16817.610200                12215.024145
# std                   14845.197632                11842.628550
# min                    6972.000000                    8.400000
# 25%                    8768.175000                 6568.500000
# 50%                   11923.250000                 8772.200000
# 75%                   18020.050000                13579.300000
# max                  137492.100000               126177.300000
#
#        Feature Streams (in millions)  Solo Streams (in millions)
# count                     468.000000                  493.000000
# mean                     5001.377137                 8442.593915
# std                      6021.629551                 9605.072797
# min                         0.400000                    1.300000
# 25%                       971.450000                 2755.300000
# ...

# %%
df.columns
# Out:
# Index(['Artist', 'Sex', 'Country', 'Langugage', 'Primary Genre',
#        ' Artist Type', 'Total Streams (in millions)',
#        'Lead Streams (in millions)', 'Feature Streams (in millions)',
#        'Solo Streams (in millions)'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Artist                            object
# Sex                               object
# Country                           object
# Langugage                         object
# Primary Genre                     object
#  Artist Type                      object
# Total Streams (in millions)      float64
# Lead Streams (in millions)       float64
# Feature Streams (in millions)    float64
# Solo Streams (in millions)       float64
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=500, step=1)

# %%
df.size
# Out:
# 5000

# %%
df["Sex"].unique()
# Out:
# array(['Male', 'Female', 'Mixed'], dtype=object)

# %%
df["Sex"].nunique()
# Out:
# 3

# %%
df["Country"].unique()
# Out:
# array(['Canada', 'United States', 'United Kingdom', 'Barbados',
#        'Colombia', 'South Korea', 'Trinidad and Tobago', 'France',
#        'India', 'Scotland', 'Mexico', 'Australia', 'Germany', 'Cuba',
#        'Sweden', 'Norway', 'Panama', 'Brazil', 'Netherlands', 'Jamaica',
#        'Senegal', 'Ireland', 'Argentina', 'Spain', 'Japan', 'New Zealand',
#        'Morocco', 'Chile', 'Russia', 'Nigeria', 'South Africa',
#        'Venezuela', 'Italy', 'Dominican Republic', 'Belgium', 'DR Congo',
#        'Nepal', 'Pakistan', 'Guatemala', 'Austria', 'Philippines',
#        'Denmark', 'Iceland'], dtype=object)

# %%
df.loc[2,"Sex"]
# Out:
# 'Male'

# %%
df.iloc[2,0]
# Out:
# 'Bad Bunny'

# %%
df.loc[2,"Country"]
# Out:
# 'United States'

# %%
df.iloc[2,0]
# Out:
# 'Bad Bunny'

# %%
df.loc[0]
# Out:
# Artist                              Drake
# Sex                                  Male
# Country                            Canada
# Langugage                         English
# Primary Genre                     Hip-Hop
#  Artist Type                         Solo
# Total Streams (in millions)      137492.1
# Lead Streams (in millions)        94851.1
# Feature Streams (in millions)     42640.9
# Solo Streams (in millions)        53323.9
# Name: 0, dtype: object

# %%
import pandas as pd
pd.options.display.max_rows
# Out:
# 60

# %%
import pandas as pd
data={
  "calories":[420,30,390],
  "duration":[50,40,45]
  }
myvar=pd.DataFrame(data)
print(myvar)
# Out:
#    calories  duration
# 0       420        50
# 1        30        40
# 2       390        45

# %%
import pandas as pd
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Artist                         500 non-null    object
#  1   Sex                            500 non-null    object
#  2   Country                        500 non-null    object
#  3   Langugage                      500 non-null    object
#  4   Primary Genre                  500 non-null    object
#  5    Artist Type                   500 non-null    object
#  6   Total Streams (in millions)    500 non-null    float64
#  7   Lead Streams (in millions)     497 non-null    float64
#  8   Feature Streams (in millions)  468 non-null    float64
#  9   Solo Streams (in millions)     493 non-null    float64
# dtypes: float64(4), object(6)
# memory usage: 39.2+ KB

# %%
df["Langugage"]=="English"
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 495     True
# 496     True
# 497     True
# 498     True
# 499    False
# Name: Langugage, Length: 500, dtype: bool

# %%
df["Langugage"]!="English"
#everything except English.
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499     True
# Name: Langugage, Length: 500, dtype: bool

# %%
df[df["Lead Streams (in millions)"]>10000]
# Out:
#                                              Artist     Sex         Country  \
# 0                                             Drake    Male          Canada
# 1                                      Taylor Swift  Female   United States
# 2                                         Bad Bunny    Male   United States
# 3                                        The Weeknd    Male          Canada
# 4                                     Justin Bieber    Male          Canada
# ..                                              ...     ...             ...
# 298                                    Foo Fighters    Male   United States
# 299                                        The 1975    Male  United Kingdom
# 305                                      Conan Gray    Male   United States
# 310                             My Chemical Romance    Male   United States
# 314  La Arrolladora Banda El LimÃ³n De Rene Camacho    Male          Mexico
#
# ...

# %%
is_United_States=df["Country"]=="United States"
is_viewed=df["Lead Streams (in millions)"]>10000
df[is_United_States & is_viewed]
# Out:
#                   Artist     Sex        Country Langugage Primary Genre  \
# 1           Taylor Swift  Female  United States   English           Pop
# 2              Bad Bunny    Male  United States   Spanish     Reggaeton
# 5          Ariana Grande  Female  United States   English           Pop
# 6           Travis Scott    Male  United States   English       Hip-Hop
# 7             Kanye West    Male  United States   English       Hip-Hop
# ..                   ...     ...            ...       ...           ...
# 290            blink-182    Male  United States   English          Rock
# 297             Aventura    Male  United States   Spanish       Bachata
# 298         Foo Fighters    Male  United States   English          Rock
# 305           Conan Gray    Male  United States   English           Pop
# 310  My Chemical Romance    Male  United States   English          Rock
#
#      Artist Type  Total Streams (in millions)  Lead Streams (in millions)  \
# ...

# %%
len(is_United_States)
# Out:
# 500

# %%
is_United_States.shape
# Out:
# (500,)

# %%
is_United_States=df["Country"]=="United States"
is_viewed=df["Lead Streams (in millions)"]>10000
df[is_United_States | is_viewed]
# Out:
#             Artist     Sex        Country Langugage Primary Genre  \
# 0            Drake    Male         Canada   English       Hip-Hop
# 1     Taylor Swift  Female  United States   English           Pop
# 2        Bad Bunny    Male  United States   Spanish     Reggaeton
# 3       The Weeknd    Male         Canada   English           R&B
# 4    Justin Bieber    Male         Canada   English           Pop
# ..             ...     ...            ...       ...           ...
# 494     Jason Mraz    Male  United States   English           Pop
# 496    The MarÃ­as   Mixed  United States   English           Pop
# 497    Limp Bizkit    Male  United States   English      Nu Metal
# 498           Korn    Male  United States   English         Metal
# 499    Omar Courtz    Male  United States   Spanish     Reggaeton
#
#      Artist Type  Total Streams (in millions)  Lead Streams (in millions)  \
# 0           Solo                     137492.1                     94851.1
# ...

# %%
df[~(df["Primary Genre"]=="R&B")]
# Out:
#             Artist     Sex         Country Langugage Primary Genre  \
# 0            Drake    Male          Canada   English       Hip-Hop
# 1     Taylor Swift  Female   United States   English           Pop
# 2        Bad Bunny    Male   United States   Spanish     Reggaeton
# 4    Justin Bieber    Male          Canada   English           Pop
# 5    Ariana Grande  Female   United States   English           Pop
# ..             ...     ...             ...       ...           ...
# 495       The Cure    Male  United Kingdom   English          Rock
# 496    The MarÃ­as   Mixed   United States   English           Pop
# 497    Limp Bizkit    Male   United States   English      Nu Metal
# 498           Korn    Male   United States   English         Metal
# 499    Omar Courtz    Male   United States   Spanish     Reggaeton
#
#      Artist Type  Total Streams (in millions)  Lead Streams (in millions)  \
# 0           Solo                     137492.1                     94851.1
# ...

# %%
#between-inclusive at both ends
df[df["Lead Streams (in millions)"].between (50000,100000)]
# Out:
#            Artist     Sex         Country Langugage Primary Genre  \
# 0           Drake    Male          Canada   English       Hip-Hop
# 2       Bad Bunny    Male   United States   Spanish     Reggaeton
# 3      The Weeknd    Male          Canada   English           R&B
# 5   Ariana Grande  Female   United States   English           Pop
# 8      Ed Sheeran    Male  United Kingdom   English           Pop
# 9          Eminem    Male   United States   English       Hip-Hop
# 11  Billie Eilish  Female   United States   English           Pop
#
#     Artist Type  Total Streams (in millions)  Lead Streams (in millions)  \
# 0          Solo                     137492.1                     94851.1
# 2          Solo                     125899.8                     82189.3
# 3          Solo                      95703.2                     77189.4
# 5          Solo                      68298.9                     57097.5
# ...

# %%
df.query("`Primary Genre` == 'R&B' and `Lead Streams (in millions)` > 10000")
# Out:
#             Artist     Sex        Country Langugage Primary Genre  \
# 3       The Weeknd    Male         Canada   English           R&B
# 21     Chris Brown    Male  United States   English           R&B
# 33             SZA  Female  United States   English           R&B
# 39          Khalid    Male  United States   English           R&B
# 80     Frank Ocean    Male  United States   English           R&B
# 119          USHER    Male  United States   English           R&B
# 125     Kali Uchis  Female       Colombia   English           R&B
# 154  Daniel Caesar    Male         Canada   English           R&B
# 178           Joji    Male          Japan   English           R&B
# 180  PARTYNEXTDOOR    Male         Canada   English           R&B
# 198  Bryson Tiller    Male  United States   English           R&B
#
#      Artist Type  Total Streams (in millions)  Lead Streams (in millions)  \
# 3           Solo                      95703.2                     77189.4
# ...

# %%
df["Primary Genre"].value_counts()
# Out:
# Primary Genre
# Hip-Hop             115
# Pop                 102
# Rock                 60
# Reggaeton            43
# R&B                  31
# Latin                30
# EDM                  22
# Regional Mexican     19
# K-Pop                11
# Filmi                11
# Country              10
# Alternative           9
# Sertanjeo             9
# Metal                 8
# Folk                  4
# Soundtrack            3
# Bachata               3
# Soul                  3
# Reggae                2
# Afrobeats             2
# Spoken Word           1
# Children's Music      1
# Nu Metal              1
# Name: count, dtype: int64

# %%
df["Primary Genre"].value_counts(dropna=False)#missing values
# Out:
# Primary Genre
# Hip-Hop             115
# Pop                 102
# Rock                 60
# Reggaeton            43
# R&B                  31
# Latin                30
# EDM                  22
# Regional Mexican     19
# K-Pop                11
# Filmi                11
# Country              10
# Alternative           9
# Sertanjeo             9
# Metal                 8
# Folk                  4
# Soundtrack            3
# Bachata               3
# Soul                  3
# Reggae                2
# Afrobeats             2
# Spoken Word           1
# Children's Music      1
# Nu Metal              1
# Name: count, dtype: int64

# %%
df["Primary Genre"].unique()
# Out:
# array(['Hip-Hop', 'Pop', 'Reggaeton', 'R&B', 'K-Pop', 'Rock',
#        'Alternative', 'EDM', 'Filmi', 'Latin', 'Regional Mexican',
#        'Country', 'Spoken Word', 'Soundtrack', 'Bachata', 'Sertanjeo',
#        'Reggae', 'Folk', 'Metal', 'Afrobeats', 'Soul', "Children's Music",
#        'Nu Metal'], dtype=object)

# %%
df["Primary Genre"].nunique()
# Out:
# 23

# %% [markdown]
# Data cleaning

# %%
df.isna()#True where a value is missing
# Out:
#      Artist    Sex  Country  Langugage  Primary Genre   Artist Type  \
# 0     False  False    False      False          False         False
# 1     False  False    False      False          False         False
# 2     False  False    False      False          False         False
# 3     False  False    False      False          False         False
# 4     False  False    False      False          False         False
# ..      ...    ...      ...        ...            ...           ...
# 495   False  False    False      False          False         False
# 496   False  False    False      False          False         False
# 497   False  False    False      False          False         False
# 498   False  False    False      False          False         False
# 499   False  False    False      False          False         False
#
#      Total Streams (in millions)  Lead Streams (in millions)  \
# 0                          False                       False
# ...

# %%
df.isna().sum()
# Out:
# Artist                            0
# Sex                               0
# Country                           0
# Langugage                         0
# Primary Genre                     0
#  Artist Type                      0
# Total Streams (in millions)       0
# Lead Streams (in millions)        3
# Feature Streams (in millions)    32
# Solo Streams (in millions)        7
# dtype: int64

# %%
df.isna().sum().sum()#total across the whole table
# Out:
# np.int64(42)

# %%
df.isna().mean()*100  #percentage missing per column
# Out:
# Artist                           0.0
# Sex                              0.0
# Country                          0.0
# Langugage                        0.0
# Primary Genre                    0.0
#  Artist Type                     0.0
# Total Streams (in millions)      0.0
# Lead Streams (in millions)       0.6
# Feature Streams (in millions)    6.4
# Solo Streams (in millions)       1.4
# dtype: float64

# %%
df.dropna()
# Out:
#             Artist     Sex         Country Langugage Primary Genre  \
# 0            Drake    Male          Canada   English       Hip-Hop
# 1     Taylor Swift  Female   United States   English           Pop
# 2        Bad Bunny    Male   United States   Spanish     Reggaeton
# 3       The Weeknd    Male          Canada   English           R&B
# 4    Justin Bieber    Male          Canada   English           Pop
# ..             ...     ...             ...       ...           ...
# 495       The Cure    Male  United Kingdom   English          Rock
# 496    The MarÃ­as   Mixed   United States   English           Pop
# 497    Limp Bizkit    Male   United States   English      Nu Metal
# 498           Korn    Male   United States   English         Metal
# 499    Omar Courtz    Male   United States   Spanish     Reggaeton
#
#      Artist Type  Total Streams (in millions)  Lead Streams (in millions)  \
# 0           Solo                     137492.1                     94851.1
# ...

# %%
df["Country"].fillna(0)
# Out:
# 0              Canada
# 1       United States
# 2       United States
# 3              Canada
# 4              Canada
#             ...
# 495    United Kingdom
# 496     United States
# 497     United States
# 498     United States
# 499     United States
# Name: Country, Length: 500, dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Artist, Sex, Country, Langugage, Primary Genre,  Artist Type, Total Streams (in millions), Lead Streams (in millions), Feature Streams (in millions), Solo Streams (in millions)]
# Index: []

# %%
import pandas as pd
df = df.rename(columns={"Langugage":"Language"})

# %%
import pandas as pd
s=pd.Series(["60670.7","58049.5","N/A","56459.5"])
pd.to_numeric(s,errors="coerce")
# Out:
# 0    60670.7
# 1    58049.5
# 2        NaN
# 3    56459.5
# dtype: float64

# %%
df.describe()
# Out:
#        Total Streams (in millions)  Lead Streams (in millions)  \
# count                   500.000000                  497.000000
# mean                  16817.610200                12215.024145
# std                   14845.197632                11842.628550
# min                    6972.000000                    8.400000
# 25%                    8768.175000                 6568.500000
# 50%                   11923.250000                 8772.200000
# 75%                   18020.050000                13579.300000
# max                  137492.100000               126177.300000
#
#        Feature Streams (in millions)  Solo Streams (in millions)
# count                     468.000000                  493.000000
# mean                     5001.377137                 8442.593915
# std                      6021.629551                 9605.072797
# min                         0.400000                    1.300000
# 25%                       971.450000                 2755.300000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Artist                         500 non-null    object
#  1   Sex                            500 non-null    object
#  2   Country                        500 non-null    object
#  3   Language                       500 non-null    object
#  4   Primary Genre                  500 non-null    object
#  5    Artist Type                   500 non-null    object
#  6   Total Streams (in millions)    500 non-null    float64
#  7   Lead Streams (in millions)     497 non-null    float64
#  8   Feature Streams (in millions)  468 non-null    float64
#  9   Solo Streams (in millions)     493 non-null    float64
# dtypes: float64(4), object(6)
# memory usage: 39.2+ KB

# %% [markdown]
# #Day 3
# # Filtering and cleaning data

# %%
import pandas as pd

Country = df[df["Country"] == "United States"]

# %%
Country.to_excel("Country.xlsx", index=False)

# %%
data=pd.read_excel("/content/Country.xlsx")
data.shape
# Out:
# (265, 10)

# %%
data.head()
# Out:
#           Artist     Sex        Country Language Primary Genre  Artist Type  \
# 0   Taylor Swift  Female  United States  English           Pop         Solo
# 1      Bad Bunny    Male  United States  Spanish     Reggaeton         Solo
# 2  Ariana Grande  Female  United States  English           Pop         Solo
# 3   Travis Scott    Male  United States  English       Hip-Hop         Solo
# 4     Kanye West    Male  United States  English       Hip-Hop         Solo
#
#    Total Streams (in millions)  Lead Streams (in millions)  \
# 0                     127861.0                    126177.3
# 1                     125899.8                     82189.3
# 2                      68298.9                     57097.5
# 3                      65349.7                     35338.7
# 4                      65142.9                     46558.4
#
#    Feature Streams (in millions)  Solo Streams (in millions)
# 0                         1683.8                    113421.5
# ...

# %%
import matplotlib.pyplot as plt
lead_streams=df.groupby("Country")["Lead Streams (in millions)"].sum().sort_values()
lead_streams.plot(kind="bar")
plt.show()
