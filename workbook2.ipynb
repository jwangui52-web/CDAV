# %% [markdown]
# <a href="https://colab.research.google.com/github/jwangui52-web/CDAV/blob/main/workbook2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Q111

# %%
def words(text):
  words=text
  for words in text:
  words=(,.?-'!:;)

# %%
from posixpath import split
def sentence_splitter(sentence):
  list_of_words=sentence.split()
  final list=[]
  foe word in the list_of_words:
  cleaned_word=word.strip(",.?-(){[]}'!:;")
  final_list.append(cleanedword)
  return final_list

# %%
prompt=input("Give me a sentence")
print(sentence_splitter(prompt))
# Out:
# Give me a sentence"i am happy-ish"
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1798/4061427527.py in <cell line: 0>()
#       1 prompt=input("Give me a sentence")
# ----> 2 print(sentence_splitter(prompt))
#
# NameError: name 'sentence_splitter' is not defined

# %%
for s in sentence:
  print(sentence_splitter(s))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1798/1148902268.py in <cell line: 0>()
# ----> 1 for s in sentence:
#       2   print(sentence_splitter(s))
#
# NameError: name 'sentence' is not defined
