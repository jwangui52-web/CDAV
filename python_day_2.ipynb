# %% [markdown]
# <a href="https://colab.research.google.com/github/jwangui52-web/CDAV/blob/main/python_day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Input

# %%
name=input("what is your name? ")
# Out:
# what is your name? Wangui

# %%
name=input("what is your name?")
# Out:
# what is your name?John

# %%
food=input("what is your favourite food?")
# Out:
# what is your favourite food?pizza

# %%
sport=input("what is your favourite sport?")
# Out:
# what is your favourite sport?football

# %%
print("hello",name)
# Out:
# hello John

# %%
print("you like",food)
# Out:
# you like pizza

# %%
print("your favourite" ,sport)
# Out:
# your favourite football

# %% [markdown]
# Data types

# %%
name="John"
x=10
y=3.14
is_raining=True
is_sunny=False
print(type(is_raining))
# Out:
# <class 'bool'>

# %%
print(type(y))
# Out:
# <class 'float'>

# %% [markdown]
# Operators

# %%
print(1+1)
print(10-1)
print(20/2)
print(20*2)
print(5//2)
print(5%2)
print(5**2)
# Out:
# 2
# 9
# 10.0
# 40
# 2
# 1
# 25

# %% [markdown]
# Type casting

# %%
x=10
print(type(x))
# Out:
# <class 'int'>

# %%
x=float(x)
print(type(x))
print(x)
# Out:
# <class 'float'>
# 10.0

# %% [markdown]
# Body tmp calc
#
# Write a program that asks users for their body temp in celcius and converts it to "frnht"

# %%
degree=int(input("what is your body temperature?"))
# Out:
# what is your body temperature?37

# %%
d=int(37)
print(type(37))
# Out:
# <class 'int'>

# %%
print(37)
# Out:
# 37

# %%
print((37*1.8)+32)
# Out:
# 98.60000000000001

# %% [markdown]
# mini calc

# %%
val1=int(input("enter a value"))
val2=int(input("enter another"))
print("sum",val1+val2)
print("minus",val1-val2)
print("multiply",val1*val2)
print("divide",val1/val2)
print("power",val1**val2)
# Out:
# enter a value6
# enter another2
# sum 8
# minus 4
# multiply 12
# divide 3.0
# power 36
