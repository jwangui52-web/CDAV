# %% [markdown]
# <a href="https://colab.research.google.com/github/jwangui52-web/CDAV/blob/main/Numpy3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
marks=np.array([
    [78,81,74,90],
    [65,72,80,76],
    [92,88,95,91],
    [55,60,58,63],
    [84,79,86,88]
])

# %%
marks[0]
# Out:
# array([78, 81, 74, 90])

# %%
marks[0][-1]
# Out:
# np.int64(90)

# %%
marks[1][-3]
# Out:
# np.int64(72)

# %%
marks.shape
# Out:
# (5, 4)

# %%
marks.ndim
# Out:
# 2

# %%
marks.size
# Out:
# 20

# %%
marks[1][1]
# Out:
# np.int64(72)

# %%
marks[ :,0]
# Out:
# array([78, 65, 92, 55, 84])

# %%
marks[ :,1]
# Out:
# array([81, 72, 88, 60, 79])

# %%
marks[ :, :]
# Out:
# array([[78, 81, 74, 90],
#        [65, 72, 80, 76],
#        [92, 88, 95, 91],
#        [55, 60, 58, 63],
#        [84, 79, 86, 88]])

# %%
marks[2:5,2:4]
# Out:
# array([[95, 91],
#        [58, 63],
#        [86, 88]])

# %%
marks[ :3]
# Out:
# array([[78, 81, 74, 90],
#        [65, 72, 80, 76],
#        [92, 88, 95, 91]])

# %%
marks[:,0:2]
# Out:
# array([[78, 81],
#        [65, 72],
#        [92, 88],
#        [55, 60],
#        [84, 79]])

# %%
a=np.array([8,3,6])
print(np.argmin(a))
# Out:
# 1
