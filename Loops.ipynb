# %% [markdown]
# <a href="https://colab.research.google.com/github/jwangui52-web/CDAV/blob/main/Loops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #while loop

# %%
counter=0
while counter<5:
   print("Hello world")
   counter=counter +5
# Out:
# Hello world

# %%
counter=1
while counter<5:
   print("Hellow world")
   counter=counter +1
# Out:
# Hellow world
# Hellow world
# Hellow world
# Hellow world

# %% [markdown]
# #***
# #******
# #*********

# %%
counter=1
while counter<=3:
  print("***"*counter)
  counter=counter+1
# Out:
# ***
# ******
# *********

# %%
password_incorrect=True
password="secret"
while password_incorrect:
  user_pass=input("enter the password")
  if user_pass==password:
    print("welcome back.You are logged in")
    password_incorrect=False
  else:
    print("password incorrect!!!Please try again")
# Out:
# enter the passwordsecret
# welcome back.You are logged in

# %%
counter=1
pieces=16
while counter<7:
 print(" "*counter)+
 counter=counter+1
# Out:
# ******
# ************
# ******************
# ************************
# ******************************
# ************************************
# ******************************************

# %%
not_entered_zero=True
no_of_items=0
total=0
while not_entered_zero:
  val=float(input("Enter a value"))
  if val==0:
    print(total/no_of_items)
    not_entered_zero=False
  else:
    total=val+total
    no_of_items=no_of_items+1
# Out:
# Enter a value2
# Enter a value4

# %%
sentence=input("Enter a sentence")
print("sentence")
# Out:
# Enter a sentenceI love python
# sentence

# %% [markdown]
# #formartting with f-string

# %%
name=input("Enter your name")
score=input("Enter your score")
greeting=f"Hi{name},you scored{score}!"
print(greeting)
# Out:
# Enter your nameKui
# Enter your score89
# HiKui,you scored89!

# %%
phrase="I love python"
phrase=phrase.replace("love","enjoy")
print(phrase)
# Out:
# I enjoy python

# %%
name="Lucy"
print(name)
# Out:
# Lucy

# %%
name=name.upper()
print(name)
# Out:
# LUCY

# %% [markdown]
# #loops

# %%
price="age of the guest"
price=input("age of the guest")
while without_charge<2:
  print(admitted)

# %%
palindrome="identical forward and backwards"
palindrome=input("Enter a palindrome word.")
print(palindrome)
# Out:
# Enter a palindrome word.level
# level

# %%
palindrome=True
while palindrome:
 palindrome=input("Enter a palindrome word.")
if palindrome:
  print(True)
else:
  print(not palindrome)
# Out:
# Enter a palindrome word.level
# Enter a palindrome word.ratio
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_772/4268125042.py in <cell line: 0>()
#       1 palindrome=True
#       2 while palindrome:
# ----> 3  palindrome=input("Enter a palindrome word.")
#       4 if palindrome:
#       5   print(True)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
n=int(input("positive integer "))
m=int(input("positive integer "))
# d=min(n,m)
if m<n:
  d=m
else:
  d=n
while m%d!=0 or n%d!=0:
  d=d-1
print(d ,"is the greatest common divisor of" ,n, "and", m)
# Out:
# positive integer 6
# positive integer 4
# 2 is the greatest common divisor of 6 and 4
