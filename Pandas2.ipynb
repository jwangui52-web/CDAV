# %% [markdown]
# <a href="https://colab.research.google.com/github/jwangui52-web/CDAV/blob/main/Pandas2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.2'

# %%
df=pd.read_csv("/content/kenya_transactions_messy.csv")

# %%
df.head()
# Out:
#      Txn ID        Full Name  County   Amount Paid     Txn Date   Paid Date  \
# 0  TXN00729   Wanjiku,  Jane  NAIROBI            76  22/02/2026  12/03/2026
# 1  TXN00798  Onyango, Victor   Kisumu             -  03/06/2026         NaN
# 2  TXN00672    Muthoni, John   Kiambu          6920  26/04/2026  11/05/2026
# 3  TXN00660   Barasa,  David  Kajiado          4342  21/02/2026  05/03/2026
# 4  TXN00830  Kimani, Michael   Kisumu           452  11/03/2026  10/04/2026
#
#    Rainfall mm Status
# 0        222.9      ?
# 1        902.6      P
# 2       1122.0      P
# 3        509.3      P
# 4       1193.9      P

# %%
df.tail()
# Out:
#        Txn ID        Full Name    County   Amount Paid     Txn Date  \
# 995  TXN00248  Rotich, Stephen    Nairobi         11105  06/06/2026
# 996  TXN00314     Auma, Samuel    Mombasa         17377  17/01/2026
# 997  TXN00225    Barasa, David     Kisumu           153  05/04/2026
# 998  TXN00712  Cheruiyot, Jane   Kericho           4862  09/02/2026
# 999  TXN00074  Nyongesa, Joyce   Nairobi           1021  05/02/2026
#
#       Paid Date  Rainfall mm Status
# 995  18/06/2026        896.8    NaN
# 996         NaN        639.9      P
# 997  18/04/2026       1208.0      U
# 998  14/02/2026       1636.0    NaN
# 999  15/02/2026          NaN      P

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Txn ID         1000 non-null   object
#  1   Full Name      1000 non-null   object
#  2   County         993 non-null    object
#  3    Amount Paid   960 non-null    object
#  4   Txn Date       1000 non-null   object
#  5   Paid Date      849 non-null    object
#  6   Rainfall mm    963 non-null    float64
#  7   Status         879 non-null    object
# dtypes: float64(1), object(7)
# memory usage: 62.6+ KB

# %%
df.describe(include="all")
# Out:
#           Txn ID    Full Name  County   Amount Paid     Txn Date   Paid Date  \
# count       1000         1000      993           960        1000         849
# unique       945          663       44           818         184         199
# top     TXN00830  Kimani, Ann  Mombasa             -  16/02/2026  06/05/2026
# freq           3            6      119            20          12          12
# mean         NaN          NaN      NaN           NaN         NaN         NaN
# std          NaN          NaN      NaN           NaN         NaN         NaN
# min          NaN          NaN      NaN           NaN         NaN         NaN
# 25%          NaN          NaN      NaN           NaN         NaN         NaN
# 50%          NaN          NaN      NaN           NaN         NaN         NaN
# 75%          NaN          NaN      NaN           NaN         NaN         NaN
# max          NaN          NaN      NaN           NaN         NaN         NaN
#
#         Rainfall mm Status
# ...

# %%
df.duplicated().sum()#shows the number of repeated rows.
# Out:
# np.int64(40)

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997     True
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df[df.duplicated()]
# Out:
#        Txn ID         Full Name    County   Amount Paid     Txn Date  \
# 161  TXN00750     Wafula, Mercy     Nakuru          -260  28/01/2026
# 235  TXN00562    Waweru, Samuel     Kiambu           754  23/06/2026
# 263  TXN00855   Muthoni, Samuel     Kitale           496  04/01/2026
# 286  TXN00001    Kiptoo, Samuel     Kiambu           608  24/01/2026
# 314  TXN00840      Korir, Alice    Kericho          3805  22/05/2026
# 320  TXN00734     Omondi, Grace    nairobi      4507 KES  05/02/2026
# 423  TXN00148     Muthoni, Paul    nairobi          3042  18/02/2026
# 445  TXN00772    Ochieng, James    BUNGOMA     3,193 KES  18/05/2026
# 473  TXN00660    Barasa,  David    Kajiado          4342  21/02/2026
# 497  TXN00418   Ochieng, Dennis   Kakamega             -  28/05/2026
# 500  TXN00770    Mwangi,  Felix       Meru          2437  11/01/2026
# 506  TXN00517       Kimani, Ann    Mombasa            96  13/06/2026
# 539  TXN00917       Auma, Grace    Nairobi       131 KES  24/03/2026
# ...

# %%
df.drop_duplicates()
# Out:
#        Txn ID        Full Name    County   Amount Paid     Txn Date  \
# 0    TXN00729   Wanjiku,  Jane    NAIROBI            76  22/02/2026
# 1    TXN00798  Onyango, Victor     Kisumu             -  03/06/2026
# 2    TXN00672    Muthoni, John     Kiambu          6920  26/04/2026
# 3    TXN00660   Barasa,  David    Kajiado          4342  21/02/2026
# 4    TXN00830  Kimani, Michael     Kisumu           452  11/03/2026
# ..        ...              ...        ...           ...         ...
# 994  TXN00774      Mutua, Ruth    Nairobi           562  05/01/2026
# 995  TXN00248  Rotich, Stephen    Nairobi         11105  06/06/2026
# 996  TXN00314     Auma, Samuel    Mombasa         17377  17/01/2026
# 998  TXN00712  Cheruiyot, Jane   Kericho           4862  09/02/2026
# 999  TXN00074  Nyongesa, Joyce   Nairobi           1021  05/02/2026
#
#       Paid Date  Rainfall mm Status
# 0    12/03/2026        222.9      ?
# 1           NaN        902.6      P
# 2    11/05/2026       1122.0      P
# ...

# %%
df.isna().sum()
# Out:
# Txn ID             0
# Full Name          0
# County             7
#  Amount Paid      40
# Txn Date           0
# Paid Date        151
# Rainfall mm       37
# Status           121
# dtype: int64

# %%
df.columns = df.columns.str.strip()
df[df["Amount Paid"].isna()]
# Out:
#        Txn ID          Full Name     County Amount Paid    Txn Date  \
# 15   TXN00054     Kariuki, Nancy     Nakuru         NaN  09/03/2026
# 70   TXN00708    Wafula, Stephen     Kitale         NaN  27/02/2026
# 89   TXN00607     Odhiambo, Eric    Eldoret         NaN  26/04/2026
# 91   TXN00105   Wanjiku, Michael    Mombasa         NaN  26/01/2026
# 111  TXN00881      Rotich, Grace   Mombasa          NaN  17/01/2026
# 116  TXN00822     Onyango,  Eric     Kisumu         NaN  13/01/2026
# 118  TXN00407      Auma, Anthony    Nairobi         NaN  04/05/2026
# 152  TXN00761     Wafula,  Faith     Kiambu         NaN  27/02/2026
# 160  TXN00668       Korir, Brian       Meru         NaN  30/06/2026
# 166  TXN00084    Muthoni, Winnie   Kakamega         NaN  12/01/2026
# 233  TXN00724  Nyongesa, Anthony   Nairobi​         NaN  25/06/2026
# 241  TXN00152      Waweru, Felix    Nakuru          NaN  20/01/2026
# 249  TXN00547    Odhiambo, Nancy     Kiambu         NaN  11/03/2026
# ...

# %%
df.isnull().sum()
# Out:
# Txn ID           0
# Full Name        0
# County           7
# Amount Paid     40
# Txn Date         0
# Paid Date      151
# Rainfall mm     37
# Status         121
# dtype: int64

# %%
df['Amount Paid'] = df["Amount Paid"].fillna(0)

# %%
df.isnull().sum()
# Out:
# Txn ID           0
# Full Name        0
# County           7
# Amount Paid      0
# Txn Date         0
# Paid Date      151
# Rainfall mm     37
# Status         121
# dtype: int64

# %%
missing=pd.DataFrame({
    'missing_count': df.isnull().sum(),
    'missing_pct': (df.isnull().sum()/len(df)*100).round(1)
})
missing
# Out:
#              missing_count  missing_pct
# Txn ID                   0          0.0
# Full Name                0          0.0
# County                   7          0.7
# Amount Paid              0          0.0
# Txn Date                 0          0.0
# Paid Date              151         15.1
# Rainfall mm             37          3.7
# Status                 121         12.1

# %%
#Before-note some spaces around some names
print('Before:',df.columns.tolist())
# Out:
# Before: ['Txn ID', 'Full Name', 'County', 'Amount Paid', 'Txn Date', 'Paid Date', 'Rainfall mm', 'Status']

# %%
df.columns=(
    df.columns.str.strip()    #remove leading /trailing spaces
    .str.lower()              #make everything lowercase
    .str.replace(' ','_')     #spaces inside names become underscores
)

# %%
#verify
print('After:',df.columns.tolist())
# Out:
# After: ['txn_id', 'full_name', 'county', 'amount_paid', 'txn_date', 'paid_date', 'rainfall_mm', 'status']

# %%
print('Total rows:    ', len(df))
print('Duplicate txn_id rows:',df.duplicated('txn_id'))
# Out:
# Total rows:          1000
# Duplicate txn_id rows: 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997     True
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
#clean the county column
print('unique counties BEFORE cleaning')
