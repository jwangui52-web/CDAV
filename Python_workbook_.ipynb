# %% [markdown]
# <a href="https://colab.research.google.com/github/jwangui52-web/CDAV/blob/main/Python_workbook_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
widgets=75
gizimo=112
x=int(input("What is your total widgets order"))
y=int(input("What is your total gizimo order"))
Total=((widgets*x)+(gizimo*y))
print(Total)
# Out:
# What is your total widgets order 5
# What is your total gizimo order 6
# 1047

# %% [markdown]
# #Work Book Qs

# %%
x=float(input("cost of the meal"))
tax=0.16
tip=0.18
tax=0.16*x
tip=0.18*x
print(f"tax${tax:.2f}")
print(f"tip$){tip:.2f}")
Total=(x+tax+tip)
print(Total)
# Out:
# cost of the meal1000
# tax$160.00
# tip$)180.00
# 1340.0

# %%
n=int(input("enter a positive integer"))
total=(n*(n+1))/2
print(f"the summation of all integers from 0 to {n}is {total}")
# Out:
# enter a positive integer4
# the summation of all integers from 0 to 4is 10.0

# %% [markdown]
# #Q34

# %%
number=int(input("whether the integer is even or odd"))
if number%2==0:
  print("even")
else:
  print("odd")
# Out:
# whether the integer is even or odd10
# even

# %%
x=5
y="John"
print(type(x))
# Out:
# <class 'int'>

# %%
x=5
y=3.14
z="Hello"
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# #Q36

# %%
from ast import In
letter_alphabet=input("enter a letter in the alphabet")
is_vowel=letter_alphabet in "a,e,i,o,u"
if
# Out:
# enter a letter in the alphabetu

# %%
position=input("enter position on a chess board")
black= position in "a1b2c3d4e5f6g7h8"
white=position in "b1c2d3e4f5g6h7"
if  black:
  print("black")
elif white:
  print("white")
# Out:
# enter position on a chess boardb2
# black

# %%
sound_levels=input("sound levels in decibels")
